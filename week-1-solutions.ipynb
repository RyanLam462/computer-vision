# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dense

# %%
data = keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = data.load_data()

# %%
plt.imshow(x_train[0], cmap = plt.cm.binary)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_train = keras.utils.normalize(x_train, axis=1)
x_test = keras.utils.normalize(x_test, axis=1)

# %%
model = Sequential()
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
batch_size = 128
epochs = 15
history = model.fit(x_train, y_train, 
          batch_size=batch_size, epochs=epochs, 
          validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 2s 3ms/step - loss: 0.7554 - accuracy: 0.7966 - val_loss: 0.1806 - val_accuracy: 0.9447
# Epoch 2/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1837 - accuracy: 0.9453 - val_loss: 0.1326 - val_accuracy: 0.9608
# Epoch 3/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1216 - accuracy: 0.9649 - val_loss: 0.0996 - val_accuracy: 0.9700
# Epoch 4/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0918 - accuracy: 0.9722 - val_loss: 0.0877 - val_accuracy: 0.9742
# Epoch 5/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0659 - accuracy: 0.9800 - val_loss: 0.0877 - val_accuracy: 0.9733
# Epoch 6/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0518 - accuracy: 0.9850 - val_loss: 0.0777 - val_accuracy: 0.9760
# Epoch 7/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0426 - accuracy: 0.9871 - val_loss: 0.0821 - val_accuracy: 0.9737
# Epoch 8/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 0.0741 - val_accuracy: 0.9783
# Epoch 9/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.0820 - val_accuracy: 0.9767
# Epoch 10/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0216 - accuracy: 0.9942 - val_loss: 0.0889 - val_accuracy: 0.9750
# Epoch 11/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.0871 - val_accuracy: 0.9755
# Epoch 12/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0945 - val_accuracy: 0.9753
# Epoch 13/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0937 - val_accuracy: 0.9775
# Epoch 14/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.0917 - val_accuracy: 0.9787
# Epoch 15/15
# 422/422 [==============================] - 1s 2ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0964 - val_accuracy: 0.9783

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(f"Accuracy on test data: {val_acc}")
# Out:
# 313/313 [==============================] - 0s 719us/step - loss: 0.1197 - accuracy: 0.9713
# Accuracy on test data: 0.9713000059127808

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training accuracy', 'Validation accuracy'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
